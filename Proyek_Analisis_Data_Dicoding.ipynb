# %% [markdown]
# # Proyek Analisis Data: [E-Commerce Public Dataset]
# - **Nama:** Valliska Noviana Wibisono
# - **Email:** valliskanw@student.ub.ac.id
# - **ID Dicoding:** verovallis

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa saja yang paling banyak terjual? Dalam ranking penjualan 1-10 atau top ten sales, produk apa yang menempati peringkat 10?
# - Bagaimana tingkat kepuasan customer? Produk mana yang memiliki rating tertinggi dan terendah?
# - Bagaimana performa penjualan sejauh ini?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import urllib
# !pip install unidecode
import unidecode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 5.3 MB/s eta 0:00:00
# ...

# %%
import matplotlib.image as mpimg

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# 1. Dataset Customer

# %%
customers_df = pd.read_csv('/content/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# 2. Dataset Geografis

# %%
geografis_df = pd.read_csv('/content/geolocation_dataset.csv')
geografis_df.head()
# Out:
# <ipython-input-119-6915f45eca9d>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   geografis_df = pd.read_csv('/content/geolocation_dataset.csv')
#   geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                       01037       -23.545621       -46.639292
# 1                       01046       -23.546081       -46.644820
# 2                       01046       -23.546129       -46.642951
# 3                       01041       -23.544392       -46.639499
# 4                       01035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# 3. Dataset Order Items

# %%
orderItems_df = pd.read_csv('/content/order_items_dataset.csv')
orderItems_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# 4. Dataset Order Payments

# %%
orderPayments_df = pd.read_csv('/content/order_payments_dataset.csv')
orderPayments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# 5. Dataset Order Reviews

# %%
orderReviews_df = pd.read_csv('/content/order_reviews_dataset.csv')
orderReviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# 6. Dataset Orders

# %%
orders_df = pd.read_csv('/content/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# 7. Dataset Product Category

# %%
productCategory_df = pd.read_csv('/content/product_category_name_translation.csv')
productCategory_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# 8. Dataset Products

# %%
products_df = pd.read_csv('/content/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# 9. Dataset Seller

# %%
sellers_df = pd.read_csv('/content/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# 1. Menilai Data Customer

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# 2. Menilai Data Geografis

# %%
geografis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
print("Jumlah duplikasi: ", geografis_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  261831

# %%
geografis_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %% [markdown]
# terdapat missing values

# %% [markdown]
# 3. Menilai Data Order Items

# %%
orderItems_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# Pada kolom shipping limit date, data tipenya salah

# %%
print("Jumlah duplikasi: ", orderItems_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# 4. Menilai Data Order Payments

# %%
orderPayments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
print("Jumlah duplikasi: ", orderPayments_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orderPayments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# 5. Menilai Data Order Reviews

# %%
orderReviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# pada kolom review_creation_date dan review_answer_timestamp, tipe datanya salah

# %%
print("Jumlah duplikasi: ", orderReviews_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orderReviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# terdapat missing values

# %% [markdown]
# 6. Menilai Data Orders

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# pada kolom review_Creation_Date dan review_answer_timestamp tipe datanya salah

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Terdapat missing values

# %% [markdown]
# 7. Menilai Data Product Category

# %%
productCategory_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
print("Jumlah duplikasi: ", productCategory_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# 8. Menilai Data Product

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# terdapat missing values

# %% [markdown]
# 9. Menilai Data Sellers

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# 1. Mengubah tipe data object menjadi date pada kolom shipping_limit_date

# %%
datetime = ["shipping_limit_date"]

for column in datetime:
  orderItems_df[column] = pd.to_datetime(orderItems_df[column])

# %%
orderItems_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# 2. Data frame Order Reviews
# - Mengubah data dari data frame order reviews yang memiliki missing values / kolomnya berupa null menjadi tidak null
# - Mengubah tipe data objek menjadi date pada kolom review_creation_date dan objek menjadi timestamp pada kolom
# review_answer_timestamp

# %%
orderReviews_df[orderReviews_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
orderReviews_df[orderReviews_df.review_comment_message.isna()]
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
orderReviews_df.review_comment_title.value_counts()
# Out:
# The customer didn't give a comment.    87656
# Recomendo                                423
# recomendo                                345
# Bom                                      293
# super recomendo                          270
#                                        ...
# Luminaria sobrepor led 18                  1
# Não recebi.                                1
# produto com lacre violado                  1
# Atraso Entrega                             1
# Foto enganosa                              1
# Name: review_comment_title, Length: 4528, dtype: int64

# %%
orderReviews_df.review_comment_message.value_counts()
# Out:
# The customer didn't give a comment.                                                                                                                                                                    58247
# Muito bom                                                                                                                                                                                                230
# Bom                                                                                                                                                                                                      189
# muito bom                                                                                                                                                                                                122
# ...

# %%
orderReviews_df.fillna(value="The customer didn't give a comment.", inplace=True)

# %%
datetime = ["review_creation_date","review_answer_timestamp"]

for column in datetime:
  orderReviews_df[column] = pd.to_datetime(orderReviews_df[column])

# %%
orderReviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# 2. Data frame Orders
# - Mengubah data dari data frame orders yang memiliki missing values / kolomnya berupa null menjadi tidak null
# - Mengubah tipe data objek menjadi date pada kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, dan order_estimated_delivery_date

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
datetime = ["order_purchase_timestamp","order_approved_at","order_delivered_carrier_date","order_delivered_customer_date","order_estimated_delivery_date"]

for column in datetime :
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Data Customers

# %%
customers_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 97092  9a2abd31e22fe634141b8aad28fbe154  e52d8bf5666be73028f2573fb19d1304
# 81427  e2272ac8bf459f44d6c463d1b75afb8b  fc6110afce6807f3b7834f7091a032a3
# 57359  673560cc159eac21c63a171e1afc39b1  abc88e81b409affa363ad0ac659dc8fb
# 82710  434dc66083e0ce3920a49a32c18181e6  91d7fe4f2e407bee69ad391caaced497
# 9589   b9b2aad89859ca1b04125624f2a22395  7c31429c12fa5c7e965792e0b153314f
#
#        customer_zip_code_prefix    customer_city customer_state
# 97092                     22081   rio de janeiro             RJ
# 81427                      4580        sao paulo             SP
# 57359                      6763  taboao da serra             SP
# 82710                     97110      santa maria             RS
# 9589                      30140   belo horizonte             MG

# %%
customers_df.groupby(by="customer_city").agg({
    "customer_id": "nunique"
}).sort_values(by="customer_id", ascending=False)
# Out:
#                 customer_id
# customer_city
# sao paulo             15540
# rio de janeiro         6882
# belo horizonte         2773
# brasilia               2131
# curitiba               1521
# ...                     ...
# ibiara                    1
# rio espera                1
# rio dos indios            1
# rio dos cedros            1
# lagoao                    1
#
# [4119 rows x 1 columns]

# %%
customers_df.groupby(by="customer_state").agg({
    "customer_id": "nunique"
}).sort_values(by="customer_id", ascending=False)
# Out:
#                 customer_id
# customer_state
# SP                    41746
# RJ                    12852
# MG                    11635
# RS                     5466
# PR                     5045
# SC                     3637
# BA                     3380
# DF                     2140
# ES                     2033
# GO                     2020
# PE                     1652
# CE                     1336
# PA                      975
# MT                      907
# MA                      747
# MS                      715
# PB                      536
# PI                      495
# RN                      485
# AL                      413
# SE                      350
# TO                      280
# RO                      253
# AM                      148
# AC                       81
# AP                       68
# RR                       46

# %% [markdown]
# ### Explore Data Geolocation

# %%
geografis_df.describe(include='all')
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# ...

# %%
geografis_df.groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 20056       1
# 76370       1
# 63012       1
# 76372       1
# 32635       1
# Length: 19015, dtype: int64

# %%
geografis_df.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 94265                          4545       -23.593159       -46.674037
# 430783                        21520       -22.809550       -43.365556
# 504676                        27213       -22.505196       -44.092189
# 266078                        11900       -24.502986       -47.846311
# 435267                        21842       -22.864501       -43.475136
#
#        geolocation_city geolocation_state
# 94265         sao paulo                SP
# 430783   rio de janeiro                RJ
# 504676    volta redonda                RJ
# 266078         registro                SP
# 435267   rio de janeiro                RJ

# %%
geografis_df[geografis_df['geolocation_zip_code_prefix'] == 27213].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 503017                        27213       -22.505695       -44.088639
# 503043                        27213       -22.502997       -44.088251
# 503046                        27213       -22.502997       -44.088251
# 503096                        27213       -22.505695       -44.088639
# 503110                        27213       -22.505196       -44.092189
#
#        geolocation_city geolocation_state
# 503017    volta redonda                RJ
# 503043    volta redonda                RJ
# 503046    volta redonda                RJ
# 503096    volta redonda                RJ
# 503110    volta redonda                RJ

# %% [markdown]
# ### Explore Data Order Items + Sellers

# %%
sellersItems_df = pd.merge(
    left=orderItems_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
sellersItems_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
sellersItems_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %%
sellersItems_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# Name: seller_id, dtype: int64

# %% [markdown]
# ### Explore Data Orders

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 13488  d821c07a40e746ac3f4ae3799b19ddee  ed678437e137359ba38a1f1b55dea52c
# 68531  484e1ab05a56b8ad354e449200a41742  2fad067280027bc81969116c5516ba2f
# 76228  9764559652cd9a07586f59136848e1f1  57c2f085b05b55969f44246acdf2b5ae
# 56503  61ece6128fbdf0024d0bc2e6a816b1ff  7dfcd47ecae5860d7c47befdc84c7d4e
# 26517  ef99b2344297c6e5a84acfc73ab41470  cd08333efebc859d377ad0bf63d3cbc1
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 13488    delivered      2018-02-23 06:14:54 2018-02-23 06:30:43
# 68531    delivered      2017-12-27 17:50:31 2017-12-27 19:48:14
# 76228    delivered      2017-12-06 13:05:37 2017-12-06 13:12:34
# 56503    delivered      2017-05-11 14:12:53 2017-05-11 14:22:25
# 26517    delivered      2018-03-21 22:29:44 2018-03-21 22:48:29
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 13488          2018-02-27 01:04:31           2018-03-14 17:58:18
# ...

# %%
orders_df['order_purchase_timestamp'] = pd.to_datetime(orders_df['order_purchase_timestamp'])
orders_df['order_approved_at'] = pd.to_datetime(orders_df['order_approved_at'])


orders_df['processing_time'] = orders_df['order_approved_at'] - orders_df['order_purchase_timestamp']

print(orders_df[['order_id', 'customer_id', 'processing_time']])
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       processing_time
# 0     0 days 00:10:42
# 1     1 days 06:42:50
# ...

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 62012  0fb352660f2116aecdfb1f2644b5c061  49b81dbcc4f425cf74e99577b3e847a9
# 49837  74f9ee0e66467cc93728042775469e4e  1cbe9451567408725b5ab9c1b6f848eb
# 56713  67295f84fa8af9e57a89d851ccd9cec9  efbad0e343e190019792deb0edcd832c
# 94224  78db0b29049b6795343e2a8ba2f48ff7  e806ed5d5fdf4be71b5405c1d8e39b8f
# 71754  293bc7dd9611917b0037860893adb256  e86cfb0048512f8e1b9a418e4e2235f5
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 62012    delivered      2017-12-28 10:31:00 2017-12-28 10:46:34
# 49837    delivered      2017-12-17 18:45:57 2017-12-17 19:54:01
# 56713    delivered      2018-06-18 14:19:46 2018-06-19 03:57:37
# 94224      shipped      2017-11-09 22:29:00 2017-11-09 22:46:51
# 71754    delivered      2018-01-28 20:09:15 2018-01-28 20:17:30
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 62012          2018-01-02 19:34:02           2018-01-09 22:54:48
# ...

# %%
orders_df.processing_time.describe()
# Out:
# count                        99281
# mean     0 days 10:25:08.739486910
# std      1 days 02:02:16.813098347
# min                0 days 00:00:00
# 25%                0 days 00:12:54
# 50%                0 days 00:20:36
# 75%                0 days 14:34:51
# max              187 days 21:10:50
# Name: processing_time, dtype: object

# %% [markdown]
# ### Explore Data Orders & Customers

# %%
ordersCustomers_df = pd.merge(
    left=customers_df,
    right=orders_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
ordersCustomers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
ordersCustomers_df.groupby(by="customer_zip_code_prefix").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_zip_code_prefix
# 22790    142
# 24220    124
# 22793    121
# 24230    117
# 22775    110
# 29101    101
# 13212     95
# 35162     93
# 22631     89
# 38400     87
# Name: order_id, dtype: int64

# %%
ordersCustomers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: order_id, dtype: int64

# %%
ordersCustomers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: order_id, dtype: int64

# %%
ordersCustomers_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %%
ordersCustomers_df.groupby(by="processing_time").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# processing_time
# 0 days 00:00:00    1296
# 0 days 00:12:10     120
# 0 days 00:11:37     115
# 0 days 00:11:21     113
# 0 days 00:12:40     113
# 0 days 00:12:02     112
# 0 days 00:10:17     108
# 0 days 00:12:55     107
# 0 days 00:13:09     107
# 0 days 00:11:44     107
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore Data Products & Category

# %%
procat_df = pd.merge(
    left=products_df,
    right=productCategory_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
procat_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
procat_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
procat_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# ### Explore Data Item Seller & Products

# %%
sellProducts_df = pd.merge(
    left=products_df,
    right=sellersItems_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sellProducts_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellProducts_df.groupby(by="product_category_name").agg({
    "order_id": "nunique",
    "price":  ["min", "max"]
})
# Out:
#                           order_id  price
#                            nunique    min      max
# product_category_name
# agro_industria_e_comercio      182  12.99  2990.00
# alimentos                      450   9.99   274.99
# alimentos_bebidas              227   6.50   699.90
# artes                          202   3.50  6499.00
# artes_e_artesanato              23   9.80   289.49
# ...                            ...    ...      ...
# sinalizacao_e_seguranca        140   4.50   740.00
# tablets_impressao_imagem        79  14.90   889.99
# telefonia                     4199   5.00  2428.00
# telefonia_fixa                 217   6.00  1790.00
# utilidades_domesticas         5884   3.06  6735.00
#
# [73 rows x 3 columns]

# %% [markdown]
# ### Explore Data Payment

# %%
orderPayments_df.sample(5)
# Out:
#                                 order_id  payment_sequential payment_type  \
# 37658   29ae0692b28230c48573dd73920619c2                   1       boleto
# 78688   30c26d11b6d707abbd543b6d1910106d                   1  credit_card
# 73485   b8ed3984a255598afb99a0ee70c3d45d                   1  credit_card
# 103785  b31eac1961980ead26d0df38911ac5e6                   1  credit_card
# 97537   de86d263fd8adbf70b390a50f59266e4                   1  credit_card
#
#         payment_installments  payment_value
# 37658                      1         354.98
# 78688                      3         114.35
# 73485                      1          78.20
# 103785                     1          71.15
# 97537                      1         338.77

# %%
orderPayments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
paymentsReviews_df = pd.merge(
    left=orderPayments_df,
    right=orderReviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
paymentsReviews_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score                 review_comment_title  \
# 0           1.0                        Não recomendo
# ...

# %%
paymentsReviews_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value":  ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %%
cust_df = pd.merge(
    left=ordersCustomers_df,
    right=paymentsReviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
cust_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Explore All Data

# %%
allData = pd.merge(
    left=cust_df,
    right=sellProducts_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
allData.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
allData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119143 entries, 0 to 119142
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    119143 non-null  object
#  1   customer_unique_id             119143 non-null  object
#  2   customer_zip_code_prefix       119143 non-null  int64
#  3   customer_city                  119143 non-null  object
#  4   customer_state                 119143 non-null  object
#  5   order_id                       119143 non-null  object
#  6   order_status                   119143 non-null  object
#  7   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  8   order_approved_at              118966 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   117057 non-null  datetime64[ns]
#  10  order_delivered_customer_date  115722 non-null  datetime64[ns]
# ...

# %%
allData.groupby(by=["customer_city", "product_category_name"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                              price  freight_value
# customer_city       product_category_name
# abadia dos dourados cool_stuff              199.00          20.63
#                     esporte_lazer           120.00          15.59
#                     livros_interesse_geral   39.90          18.38
# abadiania           eletroportateis         949.99          75.53
# abaete              bebes                    65.00          17.70
# ...                                            ...            ...
# ze doca             bebes                    74.80          38.07
#                     esporte_lazer           149.90          38.60
#                     ferramentas_jardim       39.90          26.61
#                     instrumentos_musicais   359.00          49.04
# zortea              informatica_acessorios   69.90          20.98
#
# [25221 rows x 2 columns]

# %%
allData.groupby(by=["customer_state", "product_category_name"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                               price  freight_value
# customer_state product_category_name
# AC             artigos_de_natal               69.90          60.95
#                automotivo                    606.97         146.42
#                bebes                         697.84         174.13
#                beleza_saude                 1386.58         268.42
#                brinquedos                    234.79          83.26
# ...                                             ...            ...
# TO             portateis_casa_forno_e_cafe  1999.00          95.44
#                relogios_presentes           5446.89         950.02
#                telefonia                    1268.12         627.34
#                telefonia_fixa               1390.99          53.58
#                utilidades_domesticas        1349.55         587.65
#
# [1368 rows x 2 columns]

# %%
allData.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 41746     7726078.35
# RJ                 12852     2795615.67
# MG                 11635     2351221.09
# RS                  5466     1160175.66
# PR                  5045     1079795.49
# BA                  3380      805070.98
# SC                  3637      801276.45
# GO                  2020      520481.65
# DF                  2140      438095.32
# ES                  2033      408611.64
# PE                  1652      380294.18
# CE                  1336      349290.36
# PA                   975      263217.70
# MT                   907      257802.26
# MA                   747      200363.24
# PB                   536      181660.73
# MS                   715      167670.27
# PI                   495      137158.89
# RN                   485      117192.91
# AL                   413      112296.47
# SE                   350       90651.44
# TO                   280       72412.08
# ...

# %%
allData.groupby(by="product_category_name").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                           order_id review_score
#                            nunique          min  max
# product_category_name
# agro_industria_e_comercio      182          1.0  5.0
# alimentos                      450          1.0  5.0
# alimentos_bebidas              227          1.0  5.0
# artes                          202          1.0  5.0
# artes_e_artesanato              23          1.0  5.0
# ...                            ...          ...  ...
# sinalizacao_e_seguranca        140          1.0  5.0
# tablets_impressao_imagem        79          1.0  5.0
# telefonia                     4199          1.0  5.0
# telefonia_fixa                 217          1.0  5.0
# utilidades_domesticas         5884          1.0  5.0
#
# [73 rows x 3 columns]

# %% [markdown]
# convert to csv

# %%
allData.to_csv('allData.csv', index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk apa saja yang paling banyak terjual? Dalam ranking penjualan 1-10 atau top ten sales, produk apa yang menempati peringkat 10?

# %%
totalPenjualan_df = allData.groupby("product_category_name")["product_id"].count().reset_index()
totalPenjualan_df = totalPenjualan_df.rename(columns={"product_category_name": "Products Name"})
totalPenjualan_df = totalPenjualan_df.rename(columns={"product_id": "Products ID"})
totalPenjualan_df = totalPenjualan_df.sort_values(by="Products ID", ascending=False)
totalPenjualan_df = totalPenjualan_df.head(10)

totalPenjualan_df.head()
# Out:
#              Products Name  Products ID
# 13         cama_mesa_banho        11988
# 11            beleza_saude        10032
# 32           esporte_lazer         9004
# 54        moveis_decoracao         8832
# 44  informatica_acessorios         8150

# %%
plt.figure(figsize=(10, 6))
plt.bar(totalPenjualan_df['Products Name'], totalPenjualan_df['Products ID'], color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Number of Products Sold')
plt.title('Top 10 Penjualan Produk')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Telihat bahwa penjualan terbanyak diraih oleh "cama_mesa_banho" dan penjualan yang perlu ditingaktakn lagi adalah "automotivo"

# %% [markdown]
# ### Pertanyaan 2: Bagaimana tingkat kepuasan customer? Produk mana yang memiliki rating tertinggi dan terendah?

# %%
ratingScores = allData['review_score'].value_counts().sort_values(ascending=False)

most_common_score = ratingScores.idxmax()

plt.figure(figsize=(10, 5))
sns.barplot(x=ratingScores.index,
            y=ratingScores.values,
            order=ratingScores.index,
            palette=["skyblue" if score == most_common_score else "grey" for score in ratingScores.index]
            )

plt.title("Kepuasan Pelanggan terhadap Pelayanan", fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Total Rate")
plt.xticks(fontsize=12)
plt.show()
# Out:
# <ipython-input-189-0ee68d3a2108>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ratingScores.index,

# %%
product_ratings = allData.groupby('product_category_name')['review_score'].mean().reset_index()

sorted_products = product_ratings.sort_values(by='review_score', ascending=False)

highest_rated_product = sorted_products.iloc[0]
print("Produk dengan rating tertinggi:")
print(highest_rated_product)

lowest_rated_product = sorted_products.iloc[-1]
print("\nProduk dengan rating terendah:")
print(lowest_rated_product)
# Out:
# Produk dengan rating tertinggi:
# product_category_name    cds_dvds_musicais
# review_score                      4.642857
# Name: 17, dtype: object
#
# Produk dengan rating terendah:
# product_category_name    seguros_e_servicos
# review_score                            2.5
# Name: 67, dtype: object

# %%
plt.figure(figsize=(10, 6))
plt.bar(sorted_products['product_category_name'], sorted_products['review_score'], color='skyblue')
plt.xlabel('Nama Kategori Produk')
plt.ylabel('Rata-rata Rating')
plt.title('Rata-rata Rating Produk per Kategori')
plt.xticks(rotation=90)
plt.tight_layout()

plt.text(0, highest_rated_product['review_score'], f"{highest_rated_product['product_category_name']}: {highest_rated_product['review_score']:.2f}", ha='center', va='bottom')
plt.text(len(sorted_products)-1, lowest_rated_product['review_score'], f"{lowest_rated_product['product_category_name']}: {lowest_rated_product['review_score']:.2f}", ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Pertanyaan Ketiga : Bagaimana performa penjualan sejauh ini?

# %%
allData['order_purchase_timestamp'] = pd.to_datetime(allData['order_purchase_timestamp'])
allData['bulan'] = allData['order_purchase_timestamp'].dt.to_period('M')

penjualan_per_bulan = allData.groupby('bulan')['price'].agg(['sum', 'mean']).reset_index()

print(penjualan_per_bulan)
# Out:
#       bulan         sum        mean
# 0   2016-09      267.36   44.560000
# 1   2016-10    51068.92  132.646545
# 2   2016-12       10.90   10.900000
# 3   2017-01   129895.32  126.974897
# 4   2017-02   262013.86  126.393565
# 5   2017-03   398117.44  124.372833
# 6   2017-04   392595.36  137.079385
# 7   2017-05   549226.84  123.560594
# 8   2017-06   456867.47  119.536230
# 9   2017-07   536906.96  109.864326
# 10  2017-08   606026.98  116.008227
# 11  2017-09   665047.38  129.487418
# 12  2017-10   697457.32  124.169008
# 13  2017-11  1055072.10  115.992975
# 14  2017-12   773574.02  117.332629
# 15  2018-01   993701.49  115.506392
# 16  2018-02   889512.29  110.884105
# 17  2018-03  1029589.67  119.831200
# 18  2018-04  1031717.62  124.724084
# 19  2018-05  1032699.42  125.464636
# 20  2018-06   910053.03  123.046651
# 21  2018-07   927401.38  126.074141
# 22  2018-08   884731.52  118.533162
# 23  2018-09      145.00  145.000000
# 24  2018-10        0.00         NaN

# %%
penjualan_per_bulan['bulan'] = penjualan_per_bulan['bulan'].astype(str) + '-01'
penjualan_per_bulan['bulan'] = pd.to_datetime(penjualan_per_bulan['bulan'])

plt.figure(figsize=(10, 6))
plt.plot(penjualan_per_bulan['bulan'], penjualan_per_bulan['sum'], marker='o', color='b', linestyle='-')
plt.xlabel('Bulan')
plt.ylabel('Total Penjualan')
plt.title('Total Penjualan per Bulan')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Produk apa saja yang paling banyak terjual? Dalam ranking penjualan 1-10 atau top ten sales, produk apa yang menempati peringkat 10?
# > Telihat bahwa penjualan terbanyak diraih oleh "cama_mesa_banho" dan penjualan yang perlu ditingaktakn lagi adalah "automotivo".
#
# - Bagaimana tingkat kepuasan customer? Produk mana yang memiliki rating tertinggi dan terendah?
#
# > Terlihat bahwa masih banyak produk yang mendapatkan rating "5", dan rating lainnya masih terlampau sedikit. Jadi dapat disimpulkan, customer cukup puas dengan pelayanan yang diberikan. Untuk produk dengan rating tertinggi adalah cds_dvds_musicais dengan skor 4.642857 dan
# Produk dengan rating terendah adalah seguros_e_servicos
# dengan skor 2.5.
#
# - Bagaimana performa penjualan sejauh ini?
#
# > Penjualan dari tahun 2016 hingga tahun 2017 terlihat terus menaik hingga cukup tinggi. namun, pada tahun 2018 mulai menurun dan sekarang kembali mencapai titik terendah.
